# %%
import matplotlib.pyplot as plt
import numpy as np
import cv2
import json
import os
import random
import shutil
from dataAugmentation import augmentDataA

# %%
image = plt.imread('Images/ImagesOriginal/frame_0155.jpg')
listIm = augmentDataA(image)
for im in listIm:
    plt.imshow(im, cmap='gray')
    plt.axis('off')
    plt.show()
