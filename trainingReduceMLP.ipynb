# %%
import json
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import Normalizer , scale, LabelEncoder, StandardScaler, LabelBinarizer, MinMaxScaler
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt
import cv2
import os
os.environ["TF_ENABLE_ONEDNN_OPTS"] = "0"
import tensorflow as tf
import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.models import load_model
from tensorflow.keras.layers import Conv2D, Dense, Dropout
from tensorflow.keras.utils import to_categorical
import seaborn as sns
from tensorflow.keras.callbacks import ModelCheckpoint  # Réimporte la classe au cas où elle a été écrasée
from dataVisualisation import viewData, viewDataDistribution

# %%
datapath = "dataReduceAugmentedV3"
viewData(datapath)
viewDataDistribution(datapath)
# Out:
# Type de data : <class 'dict'>
# {
#     "ImagesReduce\\frame_0637.jpg": {
#         "landmarks": [
#             [
#                 0.5193254351615906,
#                 0.18619215488433838,
#                 -0.20120230317115784,
#                 0.9968469738960266
#             ],
#             [
#                 0.5169669389724731,
#                 0.167844757437706,
#                 -0.1758834272623062,
#                 0.9948530793190002
#             ],
#             [
#                 0.516369640827179,
#                 0.16766095161437988,
#
# Nombre total d'images : 1000
# Répartition des labels :
# blocage_gauche: 250 images
# blocage_droit: 250 images
# coup_de_poing_gauche: 250 images
# coup_de_poing_droit: 250 images

# %%
with open(datapath, "r") as f:
    data = json.load(f)

all_features = []
all_labels = []

for image_name, infos in data.items():
    landmarks = infos["landmarks"]
    label = infos["label"]

    all_features.append(np.array(landmarks).flatten())
    all_labels.append(label)



train_features, test_features, train_label, test_label = train_test_split(
    all_features,all_labels,test_size=0.3,random_state=42,stratify=all_labels
)

lb = LabelBinarizer()
y_train = lb.fit_transform(train_label)
y_test = lb.transform(test_label)

X_train = np.array(train_features)
X_test = np.array(test_features)

scaler = MinMaxScaler()

x_train = scaler.fit_transform(X_train)
x_test = scaler.transform(X_test)

# %%
print(np.unique(y_train))  # Doit afficher [0 1]
print(np.unique(y_test))   # Doit afficher [0 1]
# Out:
# [0 1]
# [0 1]

# %%
#Building the MLP model =>
model = Sequential([
    Dense(128, activation='relu',input_shape=(132,)),
    Dense(64, activation='relu'),
    Dense(32, activation='relu'),
    Dropout(0.5),
    Dense(len(lb.classes_), activation='softmax')
])

# Model compilation =>
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# Resume
model.summary()
# Out:
# c:\Users\djibr\Documents\cours\m1P8\S2\projetAmmi\AmiEnv\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_8 (Dense)                 │ (None, 128)            │        17,024 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_9 (Dense)                 │ (None, 64)             │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_10 (Dense)                │ (None, 32)             │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 32)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_11 (Dense)                │ (None, 4)              │           132 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 27,492 (107.39 KB)
#  Trainable params: 27,492 (107.39 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
checkpoint_callback = ModelCheckpoint(
    filepath="modelMLPReduce.keras",
    monitor='val_accuracy',
    mode='max',
    save_best_only=True
)

# %%
history = model.fit(x_train, y_train, epochs=50, batch_size=32, validation_data=(x_test, y_test), callbacks=[checkpoint_callback])
# Out:
# Epoch 1/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.2974 - loss: 1.4048 - val_accuracy: 0.3867 - val_loss: 1.3513
# Epoch 2/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3712 - loss: 1.3409 - val_accuracy: 0.3633 - val_loss: 1.3290
# Epoch 3/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.3378 - loss: 1.3439 - val_accuracy: 0.5300 - val_loss: 1.2644
# Epoch 4/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4260 - loss: 1.2697 - val_accuracy: 0.4800 - val_loss: 1.2646
# Epoch 5/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.4462 - loss: 1.2559 - val_accuracy: 0.5800 - val_loss: 1.1906
# Epoch 6/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4408 - loss: 1.2290 - val_accuracy: 0.5100 - val_loss: 1.1829
# Epoch 7/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.4694 - loss: 1.2192 - val_accuracy: 0.6033 - val_loss: 1.1236
# Epoch 8/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5300 - loss: 1.1769 - val_accuracy: 0.5833 - val_loss: 1.0666
# Epoch 9/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6028 - loss: 1.0940 - val_accuracy: 0.6400 - val_loss: 1.0408
# Epoch 10/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5521 - loss: 1.0856 - val_accuracy: 0.6100 - val_loss: 0.9970
# Epoch 11/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5848 - loss: 1.0162 - val_accuracy: 0.6367 - val_loss: 0.9579
# Epoch 12/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6126 - loss: 0.9933 - val_accuracy: 0.6533 - val_loss: 0.9203
# Epoch 13/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6453 - loss: 0.9067 - val_accuracy: 0.6600 - val_loss: 0.8994
# Epoch 14/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6425 - loss: 0.9023 - val_accuracy: 0.6800 - val_loss: 0.8541
# Epoch 15/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6414 - loss: 0.8756 - val_accuracy: 0.6933 - val_loss: 0.8344
# Epoch 16/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6421 - loss: 0.8566 - val_accuracy: 0.6767 - val_loss: 0.8215
# Epoch 17/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7003 - loss: 0.8144 - val_accuracy: 0.6800 - val_loss: 0.8101
# Epoch 18/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6666 - loss: 0.8330 - val_accuracy: 0.7133 - val_loss: 0.7856
# Epoch 19/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6751 - loss: 0.7778 - val_accuracy: 0.7200 - val_loss: 0.7597
# Epoch 20/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7230 - loss: 0.7295 - val_accuracy: 0.7633 - val_loss: 0.7000
# Epoch 21/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7663 - loss: 0.6918 - val_accuracy: 0.7767 - val_loss: 0.6652
# Epoch 22/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7461 - loss: 0.6724 - val_accuracy: 0.7733 - val_loss: 0.6279
# Epoch 23/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7723 - loss: 0.6449 - val_accuracy: 0.6900 - val_loss: 0.7606
# Epoch 24/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7820 - loss: 0.6234 - val_accuracy: 0.7333 - val_loss: 0.6876
# Epoch 25/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7783 - loss: 0.6535 - val_accuracy: 0.7667 - val_loss: 0.6538
# Epoch 26/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7543 - loss: 0.6501 - val_accuracy: 0.6900 - val_loss: 0.7250
# Epoch 27/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7709 - loss: 0.6352 - val_accuracy: 0.7633 - val_loss: 0.6138
# Epoch 28/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8118 - loss: 0.5593 - val_accuracy: 0.7667 - val_loss: 0.6488
# Epoch 29/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7939 - loss: 0.5964 - val_accuracy: 0.7900 - val_loss: 0.5818
# Epoch 30/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7578 - loss: 0.6387 - val_accuracy: 0.7567 - val_loss: 0.6772
# Epoch 31/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7802 - loss: 0.6258 - val_accuracy: 0.7667 - val_loss: 0.6167
# Epoch 32/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8086 - loss: 0.5563 - val_accuracy: 0.7900 - val_loss: 0.5590
# Epoch 33/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8228 - loss: 0.5556 - val_accuracy: 0.7767 - val_loss: 0.6310
# Epoch 34/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8035 - loss: 0.5367 - val_accuracy: 0.7933 - val_loss: 0.5359
# Epoch 35/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8004 - loss: 0.5031 - val_accuracy: 0.7833 - val_loss: 0.5608
# Epoch 36/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7710 - loss: 0.5762 - val_accuracy: 0.8033 - val_loss: 0.5376
# Epoch 37/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8274 - loss: 0.4857 - val_accuracy: 0.7933 - val_loss: 0.5606
# Epoch 38/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7851 - loss: 0.5840 - val_accuracy: 0.8033 - val_loss: 0.5604
# Epoch 39/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8052 - loss: 0.4877 - val_accuracy: 0.7633 - val_loss: 0.5945
# Epoch 40/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8325 - loss: 0.4970 - val_accuracy: 0.7933 - val_loss: 0.5216
# Epoch 41/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8446 - loss: 0.4776 - val_accuracy: 0.7833 - val_loss: 0.5732
# Epoch 42/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8068 - loss: 0.5625 - val_accuracy: 0.7400 - val_loss: 0.6709
# Epoch 43/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7902 - loss: 0.5443 - val_accuracy: 0.8033 - val_loss: 0.5538
# Epoch 44/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8114 - loss: 0.5108 - val_accuracy: 0.7767 - val_loss: 0.5549
# Epoch 45/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7978 - loss: 0.5444 - val_accuracy: 0.7433 - val_loss: 0.6263
# Epoch 46/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8326 - loss: 0.5106 - val_accuracy: 0.7867 - val_loss: 0.5059
# Epoch 47/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8388 - loss: 0.4498 - val_accuracy: 0.7767 - val_loss: 0.5642
# Epoch 48/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8118 - loss: 0.4970 - val_accuracy: 0.7467 - val_loss: 0.6836
# Epoch 49/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7987 - loss: 0.5644 - val_accuracy: 0.7933 - val_loss: 0.5365
# Epoch 50/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8527 - loss: 0.4344 - val_accuracy: 0.7600 - val_loss: 0.6206

# %% [markdown]
# ## Benchmark

# %%
from tensorflow.keras.models import load_model

# Charger le meilleur modèle sauvegardé
best_model = load_model("modelMLPReduceV3.keras")

# Évaluer le modèle sur les données de test
test_loss, test_accuracy = best_model.evaluate(x_test, y_test, verbose=0)
print("Test Accuracy (best model):", test_accuracy)
# Out:
# Test Accuracy (best model): 0.8033333420753479

# %%
# Courbe de la perte
plt.subplot(1, 2, 1)
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.xlabel("Épochs")
plt.ylabel("Perte")
plt.legend()
plt.title("Évolution de la perte")
# Out:
# Text(0.5, 1.0, 'Évolution de la perte')

# %%
# Courbe de la précision
plt.subplot(1, 2, 2)
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.xlabel("Épochs")
plt.ylabel("Précision")
plt.legend()
plt.title("Évolution de la précision")
# Out:
# Text(0.5, 1.0, 'Évolution de la précision')

# %%
import time
import numpy as np
import psutil
import GPUtil
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt

model = load_model("modelMLPReduceV3.keras")

# Prédictions du modèle
y_pred = model.predict(x_test)
y_pred_classes = np.argmax(y_pred, axis=1)
y_true_classes = np.argmax(y_test, axis=1)

# Calcul des métriques
accuracy = accuracy_score(y_true_classes, y_pred_classes)
precision = precision_score(y_true_classes, y_pred_classes, average='weighted')
recall = recall_score(y_true_classes, y_pred_classes, average='weighted')
f1 = f1_score(y_true_classes, y_pred_classes, average='weighted')

print(f"Accuracy: {accuracy:.4f}")
print(f"Precision: {precision:.4f}")
print(f"Recall: {recall:.4f}")
print(f"F1-score: {f1:.4f}")
# Out:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Accuracy: 0.8033
# Precision: 0.8029
# Recall: 0.8033
# F1-score: 0.8026

# %%
class_names = lb.classes_
# Matrice de confusion
cm = confusion_matrix(y_true_classes, y_pred_classes)
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", xticklabels=class_names, yticklabels=class_names)
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.title("Confusion Matrix")
plt.show()

# %% [markdown]
# Il y a de la confusion avec les classes similaire, blocages gauche/droit. Coup-de-poing gauche/droit.
